# %% [markdown]
# # Cleanup Runner
#
# Run the cleanup script that removes the stale `frontend/` directory and obsolete root files.

# %%
from pathlib import Path
import runpy

root = Path('/workspaces/FamilyOps_AI')
script = root / 'cleanup_repo.py'
print('Running:', script)
runpy.run_path(str(script), run_name='__main__')
